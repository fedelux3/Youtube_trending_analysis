# %% [markdown]
# # Fix json data Gennaio to extract 4 download per day
#
# Questo notebook serve a estrarre esattamente 4 download per ogni giorno. Questa necessità è nata dal fatto che la presa dati in periodo covid è avvenuta ogni 6 ore in quanto ci siamo accorti che raccogliere i dati ogni 15' come facevamo inizialmente creava una rindondanza inutile nei dati.

# %% [markdown]
# Importazione delle librerie utili.

# %%
import pandas as pd
import os
import json
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta

# %% [markdown]
# Definizione della directory in cui prende i file json da pulire

# %%
path = "json\\"
file_json = "01.01.20 csv files (fede) [full day].json"

# %% [markdown]
# Definizione della funzione **find\_timestamp** che applica il fuso orario ai vari paesi

# %%
def find_timestamp(dt, country_code, c_gmt):
    fuso = c_gmt[str(country_code)]['GMT']
    diff = dt + timedelta(hours=fuso)
    r = diff.apply(datetime.strftime, format = "%m-%d-%Y %H:%M")
    return r

# %% [markdown]
# Apre il file che contiene i paesi presenti nei video con i loro fusi orari

# %%
with open("country_names.json") as file:
        country = json.load(file)
country
# Out:
# {'US': {'name': 'USA', 'GMT': -5},
#  'GB': {'name': 'Regno Unito', 'GMT': 0},
#  'IN': {'name': 'India', 'GMT': 5},
#  'DE': {'name': 'Germania', 'GMT': 1},
#  'CA': {'name': 'Canada', 'GMT': -5},
#  'FR': {'name': 'Francia', 'GMT': 1},
#  'KR': {'name': 'Corea del sud', 'GMT': 9},
#  'RU': {'name': 'Russia', 'GMT': 3},
#  'JP': {'name': 'Giappone', 'GMT': 9},
#  'BR': {'name': 'Brasile', 'GMT': -3},
#  'MX': {'name': 'Messico', 'GMT': -6},
#  'IT': {'name': 'Italia', 'GMT': 1}}

# %% [markdown]
# Apre il file in cui sono contenuti i video.

# %%
with open(path + file_json, "r") as read_file:
            j_file = json.load(read_file)
# Out:
# [{'video_id': 'Lbm3OHBHaq8',
#   'timestamp': '12-31-2019 21:14',
#   'country_code': 'BR',
#   'country_name': 'Brasile',
#   'title': '♫ RETROSPECTIVA DO FUTEBOL - 2019 | Please Me - Cardi B & Bruno Mars',
#   'publishedAt': '2019-12-31T14:18:58.000Z',
#   'channelId': 'UCGFNp4Pialo9wjT9Bo8wECA',
#   'channelTitle': 'FutParódias',
#   'categoryId': '17',
#   'category_name': 'Sports',
#   'trending_date': '20.01.01',
#   'tags': ['Futebol',
#    'FutParodias',
#    'Paródia',
#    'futparodia',
#    'futeparodia',
#    'parodia',
#    'fut parodia',
#    'fut parodias',
#    'Paródia com Jogadores',
#    'Please Me',
#    'Paródia Please Me',
#    'Paródia Cardi B',
#    'Bruno mars',
#    'Paródia Bruno Mars',
#    'Retrospectiva',
#    'Retrospectiva Futebol',
#    'Paródia Retrospectiva',
#    'Retrospectiva 2019',
#    'Futparódias 2019',
#    'Futparódias Restrospectiva',
#    'Flamengo 2019',
#    'Retrospectiva Flamengo',
#    'Liverpool',
#    'Paródia Liverpool',
#    'Brasil',
#    'Brasil Copa América',
#    'Messi',
#    'Messi 2019',
#    'Paródia Messi'],
#   'statistics': {'view_count': '700265',
#    'likes': '111345',
#    'dislikes': '1874',
#    'comment_count': '3016'},
#   'thumbnail_link': 'https://i.ytimg.com/vi/Lbm3OHBHaq8/default.jpg',
#   'description': 'Uma paródia de futebol da música Please Me de Cardi B e Bruno Mars, como tudo de melhor e pior que aconteceu no mundo futebolístico em 2019. Flamengo dominou o futebol sul-americano, Liverpool o Europeu... Também tivemos, muita zoeira, Messi melhor do mundo novamente, golaços e muito mais!\r👕 NOSSA LOJA: https://bit.ly/futlolja\r\rBora seguir nossas redes? =)\r\r👍 INSTAGRAM:\rhttps://instagram.com/dezaodrumond\rhttps://instagram.com/leonwhosoever\rhttps://instagram.com/FutParodias\r\r👍 TWITTER:\rhttps://twitter.com/dezaodrumond\rhttps://twitter.com/leonwhosoever\rhttps://twitter.com/FutParodias\r\r👍 FACEBOOK:\rhttps://facebook.com/dezaodrumond\rhttps://facebook.com/leonwhosoever\rhttps://facebook.com/FutParodias\r\r-----------------------------------------------------------------------------------------------\r\r🎼 Playback: Sing King KaraokeLink: https://youtu.be/RuMtNbMVpeM\r💻 Edição: Juan Carlos Borgonovohttps://www.youtube.com/futebolnacional-----------------------------------------------------------------------------------------------\r\rLETRA:Hã, hã, yeah, que ano!Foi bem crazy2019 foi bem crazyTeve amor de pai com o seu baby(Teve olé do além)Vish(E bike também)VishFoi bem crazy2019 foi bem crazyTeve um monte de atleta fake(Teve tela preta)Vish(E super lambreta)Vish (Uh)Nosso Brasa (Brasa) foi o grande rei (ooh)Da América (uh-huh)Nem precisou do Ney (nope)E as mina entraram firme (ow)Brasil torceu juntinho (ow)Não deu pra taça virMas deu orgulho de quem batalhou até o fim Teve quem mudou (wow) de empregador (wow)Só não deu para o Ney (Ney)Deu bom pro E.T., foi melhor do mundoBallon número 6E a melhor das Mina:Megan de RapinaRapinoe brilhou com o pé e arrebentou com a línguaDiversos craques decidiram se aposentarDar paz aos pésE o Furacão on fireLevou um troféu inédito, a Copa BRE o CruzeiroDesceu morro abaixo sem ter freioJunto com um trio fez bem feio(Foi pra Série B)Vish(Foi pra Série B)Vish (Uh)Num festejoCoxa, Sport e o Dragão CampineiroCom o Braga que acertou em cheio(Deram tchau pra B)Vish(Tão na A, bebê)Vish (Uh)Na Itália (Itália), Juve se deu bem (Ooh)E em PortugalBenfica foi o rei (wow)Deu Bayern na AlemanhaBarça na EspanhaPSG na FrançaE na Terra da Rainha o City encheu a pançaPool é brutal (-tal), não teve dó (dó)Deu um show e ergueu a Champ-Champ (hey)O timaço inglêsFoi campeão pela sexta vezE levou o Mundial (Mundial)No Mengão deu um vrau (um vrau)Numa luta dura (bem dura)Levantou a taça (oh)Mas esse fato não deixou o Mengaço pra trásDeu show de oléEm outro patamarBR e Liberta, é festa na favelaIque, babyGabigol e Bruno Henrique, babyArrancaram gol até do capim, baby(Duplão artilheiro)Vish(Duplão artilheiro)Vish (Uh)MengãoDeu o presente à sua torcidaMengãoE a torcida dedicou ao NinhoMengãoAos garotos do Ninho do UrubuE um desabafo aqui (Hã)Chega desse racismo (Chega)Quando é que vão resolver prender, punir?Ei, rapeize (uh)Vamo voltar pros trem crazy (uh, ooh)Zagueirão perdido sem o Waze (yes)(Que dibre foi esse)Vish(Que dibre foi esse)Vish (Uh)Foi bem crazyEsse ano foi bem crazyTeve minimíssil alucicrazy(Cris voando bem)Vish(Que ano do além)Vish (Uh)'},
#  {'video_id': 'jk5Y4jmgUzg',
#   'timestamp': '12-31-2019 21:14',
#   'country_code': 'BR',
#   'country_name': 'Brasile',
#   'title': 'TENHO ALGO PRA FALAR...',
#   'publishedAt': '2019-12-31T14:02:04.000Z',
#   'channelId': 'UCoTM-vvs2hnv2mCvzNJ5uXA',
#   'channelTitle': 'Franciny Ehlke',
#   'categoryId': '22',
#   'category_name': 'People & Blogs',
#   'trending_date': '20.01.01',
#   'tags': ['FRAN', 'FRANCINY', 'EHLKE', 'BEAUTY', 'BELEZA', 'Retrospectiva'],
#   'statistics': {'view_count': '340864',
#    'likes': '78643',
#    'dislikes': '811',
#    'comment_count': '6703'},
#   'thumbnail_link': 'https://i.ytimg.com/vi/jk5Y4jmgUzg/default.jpg',
#   'description': 'É um momento especial e de falar coisas que estão aqui dentro ❤ mas de qualquer forma, amo vocês. ➭ CLICA AQUI PARA SE INSCREVER youtube.com/francinyehlke e ative as notificações para não perder nada!! ❤'},
#  {'video_id': 'N1fmS9gzjJw',
#   'timestamp': '12-31-2019 21:14',
#   'country_code': 'BR',
#   'country_name': 'Brasile',
#   'title': 'RETROSPECTIVA MUSICAL 2019 - MrPoladoful',
#   'publishedAt': '2019-12-30T21:41:59.000Z',
#   'channelId': 'UC5gFyQ1LCdZ6xeeHz73ujQQ',
#   'channelTitle': 'MrPoladoful',
#   'categoryId': '24',
#   'category_name': 'Entertainment',
#   'trending_date': '20.01.01',
#   'tags': ['retrospectiva',
#    'retrospectiva musical',
#    'retrospectiva 2019',
#    'retrospectiva musica 2019',
#    'mrpoladoful',
#    'poladoful',
#    'polado'],
#   'statistics': {'view_count': '815203',
#    'likes': '216585',
#    'dislikes': '2388',
#    'comment_count': '10813'},
#   'thumbnail_link': 'https://i.ytimg.com/vi/N1fmS9gzjJw/default.jpg',
#   'description': 'retrospectiva musical que eu faço todo ano! Espero que gostem!➼Insta: @MrPoladoFul➼Twitter: @MrPoladoful➼ Me segue nas redes! :)EQUIPE QUE FEZ ACONTECERGabriel Dantas (MrPoladoful) - DIREÇÃO GERALAndre Loureiro - CÂMERARaul Alaune (48k produções) - MIXAGEM/MASTERIZAÇÃOArabi Mesquita - PRODUÇÃO Bárbara Ghale - FIGURINORoteiro/Criação: Gabriel DantasAnimação/Concept: Jaque VitalUM CANAL DE GABRIEL DANTASFALE COMIGO: contatopoladoful@gmail.com'},
#  {'video_id': 'U2nq2KqEeYI',
#   'timestamp': '12-31-2019 21:14',
#   'country_code': 'BR',
#   'country_name': 'Brasile',
#   'title': 'Rosa de Saron - Mire as Estrelas (Clipe Oficial)',
#   'publishedAt': '2019-12-31T17:00:11.000Z',
#   'channelId': 'UCglAoXBdPAMUxvMlqhUnJsQ',
#   'channelTitle': 'Rosa De Saron',
#   'categoryId': '10',
#   'category_name': 'Music',
#   'trending_date': '20.01.01',
#   'tags': ['Som Livre (Record Label)',
#    'Você Adora',
#    'Gospel',
#    'Pop Rock',
#    'Rock',
#    'Rosa de Saron',
#    'mire as estrelas',
#    'força',
#    'fé',
#    'coragem',
#    'motivação',
#    'ano novo',
#    'feliz ano novo',
#    'astronomia',
#    'lunação',
#    'foguete',
#    'onibus espacial',
#    'astronauta',
#    'astrologia',
#    'avô',
#    'gospel',
#    'musica catolica',
#    'religião',
#    'catolicismo',
#    'banda'],
#   'statistics': {'view_count': '73763',
#    'likes': '15615',
#    'dislikes': '87',
#    'comment_count': '1437'},
#   'thumbnail_link': 'https://i.ytimg.com/vi/U2nq2KqEeYI/default.jpg',
#   'description': 'Esse é o clipe oficial da música Mire as Estrelas.Contato para show:shows@rosadesaron.com.brFones: (19)3368-7981 ou (19)98115-4265MIRE AS ESTRELASBruno FaglioniEu sei que as vezes dá vontade de parar!Mas, se você desistir, quem vai lutar por você?Tanta luta pra chegar até aqui! Tanta história pra agora desistir?Caso aconteça, deixe o cansaço pra trásE nunca se esqueça: por aqui não há tarde demais!Então mire as estrelas e salte o mais alto que der!Tome distância, e faça o melhor que puder!Só não se permita viver na sombra do talvez...Aqui só se vive uma vez!Muitos medos vão tentar te segurar muitas vozes vão dizer que não vai dar! Sempre persista, não importa o que vão dizer! Só nunca desista do sonho que existe em você! Então mire as estrelas e salte o mais alto que der!Tome distância, e faça o melhor que puder!Só não se permita viver na sombra do talvez...Aqui só se vive uma vez!Vença seus medos! Você é capaz de voar por cima das vozesQue gritam pra você parar!Não há nesta vida algo que não se possa alcançar...Você só precisa ir buscar!E encontrar na persistência o seu valor!E, apesar do seu cansaço, sua dor nunca se entregar!Então mire as estrelas e salte o mais alto que der!Tome distância, e faça o melhor que puder!Só não se permita viver na sombra do talvez...Aqui só se vive uma vez!Vença seus medos! Você é capaz de voar por cima das vozesQue gritam pra você parar!Não há nesta vida algo que não se possa alcançar...Você só precisa ir buscar!FICHA TÉCNICA:Produção musical: André Cavalcante (A Fabrika Produções)Produtora: Nice Pixel Entertainment Direção e Fotografia: JC NunesArte: JC Nunes e Fabi NunesAssistente de produção: Fabi Nunes, Leonardo Tomacelli, Eli Santos Produção geral: Fernanda Ventura e Fabi NunesProdução de Elenco: Fernanda VenturaMake-up: Paula CursinoEfeitos visuais (VFX): Diogo AraújoEdição e color: JC NunesAtores: Flávio Meirelles Ribeiro Amanda GazzoVitória SouzaJulia BiebeireFiguração mirim:Guilherme André Batista Mello Aguiar;Luísa Gabriele Teixeira de Moura;Maria Fernanda;Matheus Machado Gonçalves; Ícaro Serapião Dias, Fábio Campos Assis, Ariela Campos Assis, Bianca Campos AssisFiguração: Anderson Zambrini, Igor Acauã, João Mercê, Wladimir Pereira, Rogério Marco Tatá Silva, Carlos Roberto,Sr. GeraldoFigurino banda: Gisele TakedaAPOIO- Colégio Progressão de Pindamonhangaba sob a supervisão de Felipe Gomes- Escola Dinâmica Alice Nader Zarzur de Taubaté- Aeroclube Regional de Taubaté- Observatório Pico dos Dias- MAAS - Museu Aberto de Astronomia- Gisele Franco (casa)'},
#  {'video_id': 'jSIkedkw7XQ',
#   'timestamp': '12-31-2019 21:14',
#   'country_code': 'BR',
#   'country_name': 'Brasile',
#   'title': 'Parabéns, KIBIWOTT KANDIE | ULTRAPASSAGEM INACREDITÁVEL do campeão na São Silvestre 2019! (31/12/19)',
#   'publishedAt': '2019-12-31T13:00:28.000Z',
#   'channelId': 'UCcndglQZmXnYjgE_Grqt5yg',
#   'channelTitle': 'Gazeta Esportiva',
#   'categoryId': '17',
#   'category_name': 'Sports',
#   'trending_date': '20.01.01',
#   'tags': ['gazeta esportiva',
#    'GAZETA ESPORTIVA DE HOJE',
#    'notícias corinthians',
#    'notícias palmeiras',
#    'notícias são paulo',
#    'notícias santos'],
#   'statistics': {'view_count': '44289',
#    'likes': '1132',
#    'dislikes': '40',
#    'comment_count': '147'},
#   'thumbnail_link': 'https://i.ytimg.com/vi/jSIkedkw7XQ/default.jpg',
#   'description': 'Saiba TUDO sobre o seu time e o mundo dos esportes:\rhttp://www.gazetaesportiva.com\rhttp://www.facebook.com/gazetaesportiva\rhttp://www.twitter.com/gazetaesportiva\rhttp://www.instagram.com/gazetaesportiva'},
#  {'video_id': 'uahMIkjTCD4',
#   'timestamp': '12-31-2019 21:14',
#   'country_code': 'BR',
#   'country_name': 'Brasile',
#   'title': 'Poesia Free Fire #2 l ATE OS MESTRES VÃO CAIR l  Ft. VMZ, VG BITS, YURI, TAUZ',
#   'publishedAt': '2019-12-30T23:00:09.000Z',
#   'channelId': 'UCIvBHgnnLSVr9enuPvBuwyw',
#   'channelTitle': 'Piuzinho',
#   'categoryId': '10',
#   'category_name': 'Music',
#   'trending_date': '20.01.01',
#   'tags': ['FREE',
#    'FIRE',
#    'BATTLEGROUNDS',
#    'free',
#    'fire',
#    'battlegrounds',
#    'hack',
#    'HACK',
#    'mito',
#    'piuzinho',
#    'piu',
#    'Poesia',
#    'POESIA',
#    'ACUSTICA',
#    'acutica',
#    'musica',
#    'TRAP',
#    'RAP',
#    'SOM',
#    'BIT'],
#   'statistics': {'view_count': '766416',
#    'likes': '234825',
#    'dislikes': '5017',
#    'comment_count': '13222'},
#   'thumbnail_link': 'https://i.ytimg.com/vi/uahMIkjTCD4/default.jpg',
#   'description': 'FREE FIRE BATTLEGROUNDSPRA FINALIZAR O ANO COM CHAVE DE OURO !O bit é do Sidney Scacciohttps://www.youtube.com/watch?v=7E_u5EevFx0mixagem feita pelo leohammes https://www.instagram.com/leohammes/?hl=pt-brYurihttps://www.youtube.com/channel/UCIMHy7Y0naM7fnAav3Sd1OgVMZ https://www.youtube.com/channel/UCgnKIwH7COU1ellkhepcvEgTauzhttps://www.youtube.com/user/TauzOficial/featuredVG bits https://www.youtube.com/user/david15bb/videos'},
#  {'video_id': 'w4Bk18UA6c8',
#   'timestamp': '12-31-2019 21:14',
#   'country_code': 'BR',
#   'country_name': 'Brasile',
#   'title': 'RETROSPECTIVA NERD 2019',
#   'publishedAt': '2019-12-31T14:39:41.000Z',
#   'channelId': 'UCt_4wzTQqmcUvemNkeO0plA',
#   'channelTitle': 'Ei Nerd',
#   'categoryId': '24',
#   'category_name': 'Entertainment',
#   'trending_date': '20.01.01',
#   'tags': ['retrospectiva 2019',
#    'retrospectiva nerd 2019',
#    'retrospectiva ei nerd',
#    'nerd',
#    'filmes',
#    'series',
#    'series 2019',
#    'filmes 2019',
#    'animes 2019',
#    'nerd 2019'],
#   'statistics': {'view_count': '155173',
#    'likes': '39889',
#    'dislikes': '218',
#    'comment_count': '2250'},
#   'thumbnail_link': 'https://i.ytimg.com/vi/w4Bk18UA6c8/default.jpg',
#   'description': '#Retrospectiva #Nerd #2019 #EiNerdEssa é a minha retrospectiva nerd de 2019. Aprenda a desenhar animes: http://bit.ly/animesytEntre pro clube Ei Nerd: https://www.youtube.com/channel/UCt_4wzTQqmcUvemNkeO0plA/joinMusic by Epidemic Sound (http://www.epidemicsound.com/)https://www.instagram.com/petjordanCanal PETER AQUI: https://goo.gl/4RsjRSSe inscreva no Ei Nerd: http://goo.gl/J8l7PJEI NERD _http://www.einerd.com.brFacebook    : https://www.facebook.com/einerd.com.brGrupo           : https://www.facebook.com/groups/EinerdTwitter         : https://twitter.com/Ei_NerdAnuncie: isabela@einerd.com.br PETER JORDAN _https://www.facebook.com/petjordanhttps://twitter.com/peterjordan100https://www.instagram.com/petjordanMANDE UM PRESENTINHO :) Caixa Postal 95121 - Cep: 25655-970Petrópolis / RJ'},
#  {'video_id': '3dugGsVfp-E',
#   'timestamp': '12-31-2019 21:14',
#   'country_code': 'BR',
#   'country_name': 'Brasile',
#   'title': '2019 MEU MELHOR ANO ‹ EduKof ›',
#   'publishedAt': '2019-12-31T14:00:00.000Z',
#   'channelId': 'UCrGnb5RdHA9M6WGmBGYo4ZQ',
#   'channelTitle': 'AM3NlC',
#   'categoryId': '22',
#   'category_name': 'People & Blogs',
#   'trending_date': '20.01.01',
#   'tags': ['VLOG',
#    'Estados',
#    'Unidos',
#    'EUA',
#    'Brasil',
#    'Brazil',
#    'Breakmen',
#    'Casa',
#    'House'],
#   'statistics': {'view_count': '198478',
#    'likes': '39429',
#    'dislikes': '378',
#    'comment_count': '2139'},
#   'thumbnail_link': 'https://i.ytimg.com/vi/3dugGsVfp-E/default.jpg',
#   'description': 'Seja Membro Exclusivo: https://bit.ly/2M6HN1kRoupas Breakmen: https://www.breakmenshop.comCanal de Games: https://goo.gl/BHD7sB♦ Redes Sociais:Snapchat: dudukofInstagram: http://goo.gl/hYNGE6 @EduKofTwitter: https://goo.gl/feFHSj @EduKof♦ Contato Comercial: contato-edukof@hotmail.com♦ ChipArt Sociais:MEU COMPUTADOR: https://goo.gl/XUe9UVCanal: https://www.youtube.com/user/CanalChipartFacebook: https://www.facebook.com/chipart.informatica#EduKof #Breakmen'},
#  {'video_id': 'E2dAtksUZz8',
#   'timestamp': '12-31-2019 21:14',
#   'country_code': 'BR',
#   'country_name': 'Brasile',
#   'title': 'O grande ANÚNCIO',
#   'publishedAt': '2019-12-31T15:27:37.000Z',
#   'channelId': 'UCrKXYE-Y4saxVFPI7Fuuzyw',
#   'channelTitle': 'Davy Jones',
#   'categoryId': '24',
#   'category_name': 'Entertainment',
#   'trending_date': '20.01.01',
#   'tags': ['[none]'],
#   'statistics': {'view_count': '159147',
#    'likes': '37605',
#    'dislikes': '629',
#    'comment_count': '2578'},
#   'thumbnail_link': 'https://i.ytimg.com/vi/E2dAtksUZz8/default.jpg',
#   'description': 'Twitch - https://www.twitch.tv/davyjones/'},
#  {'video_id': 'E_IdH8jXNx8',
#   'timestamp': '12-31-2019 21:14',
#   'country_code': 'BR',
#   'country_name': 'Brasile',
#   'title': 'POR QUE ISSO É TÃO CARO? - GAGA (Ep. 54)',
#   'publishedAt': '2019-12-30T23:59:30.000Z',
#   'channelId': 'UCuxfOdbKQy0tgGXcm9sjHiw',
#   'channelTitle': 'Coisa de Nerd',
#   'categoryId': '28',
#   'category_name': 'Science & Technology',
#   'trending_date': '20.01.01',
#   'tags': ['leon',
#    'coisadenerd',
#    'coisa de nerd',
#    'português',
#    'brasil',
#    'pt-br',
#    'br',
#    'tecnologia',
#    'laptop',
#    'notebook',
#    'macbook',
#    'macbook pro',
#    'macbook pro 16',
#    '16 polegadas',
#    '16 inches',
#    'carteira',
#    'celular',
#    'apple',
#    'carteira que carrega celular',
#    'carteira com baterria',
#    'carregamento sem fio',
#    'fone de ouvido',
#    'headset',
#    'earphone',
#    'earbud',
#    'fone para games',
#    'fone para jogos',
#    'fone de ouvido com microfone'],
#   'statistics': {'view_count': '734663',
#    'likes': '99888',
#    'dislikes': '1184',
#    'comment_count': '2976'},
#   'thumbnail_link': 'https://i.ytimg.com/vi/E_IdH8jXNx8/default.jpg',
#   'description': 'Promoção NordVPN: https://NordVPN.com/coisadenerdCódigo: COISADENERDEste é Gambiarra A Gente Aceita. Neste episódio, mostramos o novo Macbook Pro 16 polegadas da Apple, uma carteira que carrega o celular com carregamento wireless e um earphone/headset (fone de ouvido) para games.'},
#  {'video_id': 'mGyTJtoB7Tw',
#   'timestamp': '12-31-2019 21:14',
#   'country_code': 'BR',
#   'country_name': 'Brasile',
#   'title': 'O que tem dentro do Nintendo Wii',
#   'publishedAt': '2019-12-31T14:30:03.000Z',
#   'channelId': 'UCKHhA5hN2UohhFDfNXB_cvQ',
#   'channelTitle': 'Manual do Mundo',
#   'categoryId': '28',
#   'category_name': 'Science & Technology',
#   'trending_date': '20.01.01',
#   'tags': ['como fazer',
#    'como funciona',
#    'robotica',
#    'maker',
#    'experiência',
#    'teste',
#    'ciência',
#    'tecnologia',
#    'experimento',
#    'conhecimento',
#    'ventuinha',
#    'potenciômetro',
#    'motor de passo',
#    'sensor de movimentos',
#    'video game',
#    'controle'],
#   'statistics': {'view_count': '117030',
#    'likes': '20598',
#    'dislikes': '248',
#    'comment_count': '924'},
#   'thumbnail_link': 'https://i.ytimg.com/vi/mGyTJtoB7Tw/default.jpg',
#   'description': '► Superfonte de bancada https://youtu.be/2Ou7MOVZeo4► O que tem dentro de uma TV gigante https://youtu.be/azGZHN9He74► Motor de passo https://youtu.be/Tu3YUeBtR4w► Geladeira caseira https://youtu.be/O7NuMwVCdt0► O que tem dentro de um Atari https://youtu.be/1ZMDs-FLQb8► Inscreva-se: https://youtube.com/user/iberethenorio?sub_confirmation=1Comercial: comercial@manualdomundo.com.brAssessoria de imprensa: comunicacao@manualdomundo.com.brContato: manualdomundo@manualdomundo.com.br  Site: http://manualdomundo.com.br Facebook: http://facebook.com/manualdomundo Instagram: http://instagram.com/manualdomundo Twitter: http://twitter.com/manualdomundo Pinterest: http://br.pinterest.com/manualdomundo  Facebook Mari: http://facebook.com/marifulfaroreal Instagram Mari: http://instagram.com/amarifulfaro Twitter Mari: http://twitter.com/marifulfaro  Instagram Iberê: http://instagram.com/oibere Twitter Iberê: http://twitter.com/iberethenorioCRÉDITOSDireção e apresentação: Iberê Thenório Produção executiva e apresentação: Mari FulfaroImagens: André CavalieriProdução: Fernando A. Souza / Rubens IsharaEdição e finalização de imagens: Danilo Viana 🔵Este é o canal do Manual do Mundo. Vídeos novos todas as terças, quintas e sábados. 📩Manual do Mundo Comunicação LTDA Caixa Postal 77795 CEP 05593-000 SP - SP'},
#  {'video_id': 'iUbGIvfdw18',
#   'timestamp': '12-31-2019 21:14',
#   'country_code': 'BR',
#   'country_name': 'Brasile',
#   'title': 'REVIRAVOLTA NA NEGOCIAÇÃO POR MICHAEL! FLAMENGO PUNIDO? GOLEIRO DE SAÍDA? JOGADOR SE DESPEDE E+',
#   'publishedAt': '2019-12-31T12:37:14.000Z',
#   'channelId': 'UCIpylxq_JDl2YpvTpN11p9Q',
#   'channelTitle': 'FLAZOEIRO',
#   'categoryId': '17',
#   'category_name': 'Sports',
#   'trending_date': '20.01.01',
#   'tags': ['Flamengo',
#    'Fla',
#    'Mengo',
#    'Mengão',
#    'Fla Notícias',
#    'Notícias do Flamengo',
#    'Ultimas Notícias do Flamengo',
#    'Flamengo 24 Horas',
#    'Flamengo ao vivo',
#    'Fox Sports',
#    'Globo Esporte',
#    'Treino Do Flamengo',
#    'Michael',
#    'Michael Flamengo',
#    'Michael no Flamengo',
#    'Flamengo contrata Michael',
#    'Michael acerta com o flamengo',
#    'Flamengo acerta com Michael',
#    'Gabigol',
#    'Gabigol Flamengo',
#    'Gabriel Barbosa',
#    'Alex Muralha',
#    'Rodinei',
#    'Rodinei no Internacional',
#    'Flamengo vende Jogador'],
#   'statistics': {'view_count': '123159',
#    'likes': '18122',
#    'dislikes': '262',
#    'comment_count': '808'},
#   'thumbnail_link': 'https://i.ytimg.com/vi/iUbGIvfdw18/default.jpg',
#   'description': nan},
#  {'video_id': 'Hb-WPolLtUo',
#   'timestamp': '12-31-2019 21:14',
#   'country_code': 'BR',
#   'country_name': 'Brasile',
#   'title': 'Pratto de novo A Mesa | Semana decisiva por Nacho | Inter foca em um Lateral Esquerdo',
#   'publishedAt': '2019-12-31T14:00:41.000Z',
#   'channelId': 'UC4QpkZzN08pFibmJAl213-w',
#   'channelTitle': 'Fabiano Baldasso',
#   'categoryId': '17',
#   'category_name': 'Sports',
#   'trending_date': '20.01.01',
#   'tags': ['[none]'],
#   'statistics': {'view_count': '46042',
#    'likes': '10302',
#    'dislikes': '152',
#    'comment_count': '378'},
#   'thumbnail_link': 'https://i.ytimg.com/vi/Hb-WPolLtUo/default.jpg',
#   'description': 'Principais assuntos do Inter'},
#  {'video_id': 'AlvKZ-EATIw',
#   'timestamp': '12-31-2019 21:14',
#   'country_code': 'BR',
#   'country_name': 'Brasile',
#   'title': 'Jogo Aberto - 31/12/2019 - Programa completo',
#   'publishedAt': '2019-12-31T16:11:43.000Z',
#   'channelId': 'UCZaOZdn-Y-I5ikrofkWBLgQ',
#   'channelTitle': 'Jogo Aberto',
#   'categoryId': '17',
#   'category_name': 'Sports',
#   'trending_date': '20.01.01',
#   'tags': ['corinthians',
#    'palmeiras',
#    'são paulo',
#    'santos',
#    'flamengo',
#    'futebol',
#    'campeonato brasileiro',
#    'vasco',
#    'botafogo',
#    'fluminense',
#    'csa',
#    'avaí',
#    'chapecoense',
#    'grêmio',
#    'internacional',
#    'ceará',
#    'fortaleza',
#    'cruzeiro',
#    'atlético-mg',
#    'athetico-pr',
#    'denilson',
#    'renata fan',
#    'band',
#    'band tv',
#    'jogo aberto',
#    'ronaldo giovanelli'],
#   'statistics': {'view_count': '230258',
#    'likes': '6127',
#    'dislikes': '185',
#    'comment_count': '28'},
#   'thumbnail_link': 'https://i.ytimg.com/vi/AlvKZ-EATIw/default.jpg',
#   'description': 'INSCREVA-SE NO CANAL E NÃO PERCA NENHUM DETALHE DO JOGO ABERTO. Quer ver o programa completo ao vivo? Não perca, de segunda a sexta-feira, às 11h: band.com.br/jogoabertoSiga o Jogo Aberto nas redes sociais: Instagram: https://www.instagram.com/bandjogoabertoTwitter: https://twitter.com/bandjogoabertoFacebook: https://www.facebook.com/jogoaberto'},
#  {'video_id': 'riJPOXqoScU',
#   'timestamp': '12-31-2019 21:14',
#   'country_code': 'BR',
#   'country_name': 'Brasile',
#   'title': 'IMPROVÁVEL - TORRADEIRA #24',
#   'publishedAt': '2019-12-31T11:00:11.000Z',
#   'channelId': 'UCZbgt7KIEF_755Xm14JpkCQ',
#   'channelTitle': 'Barbixas',
#   'categoryId': '23',
#   'category_name': 'Comedy',
#   'trending_date': '20.01.01',
#   'tags': ['cia barbixas de humor',
#    'humor',
#    'comédia',
#    'barbixas',
#    'engraçado',
#    'funny',
#    'comedy',
#    'anderson bizzocchi',
#    'daniel nascimento',
#    'elidio sanna',
#    'standup',
#    'stand-up',
#    'jogador:Anderson_Bizzocchi',
#    'jogador:Daniel_Nascimento',
#    'jogador:Elidio_Sanna',
#    'jogador:Leandro_Costa',
#    'mc:Allan_Benatti',
#    'músico:Andrés_Giraldo',
#    'jogo:Torradeira',
#    'dia:21_11_19',
#    'upload:31_12_19',
#    'violão',
#    'sucesso',
#    'hit',
#    'rapaz',
#    'difícil demais',
#    'segurança',
#    'bateria',
#    'afinação'],
#   'statistics': {'view_count': '67405',
#    'likes': '14998',
#    'dislikes': '39',
#    'comment_count': '405'},
#   'thumbnail_link': 'https://i.ytimg.com/vi/riJPOXqoScU/default.jpg',
#   'description': 'O mais novo sucesso de Dani & Lê!ASSISTA AO VIVO:25 e 26/01 - São Paulo (SP) - https://bit.ly/35tR24yLoja online: http://www.barbixas.com.br/loja-online.htmlSite da Cia. Barbixas de Humor: http://www.barbixas.com.br--Convidados:MC: Allan BenattiJogador: Leandro CostaMúsico: Andrés GiraldoJogo: Torradeira Regra: Os jogadores iniciam atrás da tapadeira. Ao toque da campainha do MC, jogadores levantam-se e iniciam uma cena com a formação configurada.  A cada toque da campainha do MC, uma nova configuração de jogadores se forma, iniciando uma nova cena. A cada repetição de configuração de jogadores, a mesma cena que inicialmente tinha começado deve continuar.Tema (objeto com a letra V sugerido pela plateia) : “Violão.Improvável é um espetáculo criado, encenado e produzido pela Cia. Barbixas de Humor.www.barbixas.com.brGravado no Teatro TucaDia 21/11/2019'},
#  {'video_id': 'PydLvyl3BRo',
#   'timestamp': '12-31-2019 21:14',
#   'country_code': 'BR',
#   'country_name': 'Brasile',
#   'title': 'Retrospectiva KondZilla 2019 (kondzilla.com)',
#   'publishedAt': '2019-12-31T15:00:12.000Z',
#   'channelId': 'UCffDXn7ycAzwL2LDlbyWOTw',
#   'channelTitle': 'Canal KondZilla',
#   'categoryId': '10',
#   'category_name': 'Music',
#   'trending_date': '20.01.01',
#   'tags': ['kondzilla',
#    'videoclipe',
#    'lançamento',
#    'Funk',
#    'Música de Funk',
#    'Musica de Funk',
#    'Kond',
#    'Musica',
#    'Música',
#    'musicas',
#    'músicas',
#    'mc',
#    'mcs',
#    'funks',
#    'funk2019',
#    'funks2019',
#    'músicas de funk',
#    'musicas de funk',
#    'kondzilla 2019',
#    'retrospectiva',
#    'retrospectiva 2019',
#    'retrospectiva kondzilla',
#    'retrospectiva 2020',
#    'funks 2020',
#    'novos funks 2020',
#    'retrospectiva funk',
#    'melhores momentos 2019'],
#   'statistics': {'view_count': '76433',
#    'likes': '10699',
#    'dislikes': '281',
#    'comment_count': '223'},
#   'thumbnail_link': 'https://i.ytimg.com/vi/PydLvyl3BRo/default.jpg',
#   'description': 'Confira os momentos mais marcantes do 2019 da KondZilla. Que venha 2020 e mais um ano de progresso, felicidade e aprendizado. Curta e comente o que você achou.Inscreva-se no NOVO CANAL da KondZillahttp://bit.ly/CanalPortalKondZillaOUÇA NOSSOS HITS:http://bit.ly/LançamentosFunks2019http://bit.ly/MelhoresFunksKondZilla#Funk #KondZilla #Retrospectiva2019 #PortalKondZilla  #FavelaVenceu #SomosPluralCopyright © 2019 KondZilla®. Todos os direitos reservados.'},
#  {'video_id': '7Y3ixg-NBtc',
#   'timestamp': '12-31-2019 21:14',
#   'country_code': 'BR',
#   'country_name': 'Brasile',
#   'title': 'Desafio com os melhores momentos do Canal IN!',
#   'publishedAt': '2019-12-31T12:00:04.000Z',
#   'channelId': 'UCIR9VKPE70KJ4DX2zCjHObw',
#   'channelTitle': 'Canal IN',
#   'categoryId': '24',
#   'category_name': 'Entertainment',
#   'trending_date': '20.01.01',
#   'tags': ['irmãos neto',
#    'familia neto',
#    'neto',
#    'Felipe',
#    'Luccas',
#    'Felipe Neto',
#    'Luccas Neto',
#    'Casa',
#    'felipe e lucas',
#    'bruno',
#    'familia',
#    'engraçado',
#    'humor',
#    'amizade',
#    'Quiz',
#    'Retrospectiva',
#    'Canal IN',
#    'Bruno Correa',
#    'Bruna Gomes',
#    'Matheus Marinho',
#    'retrô'],
#   'statistics': {'view_count': '94974',
#    'likes': '14682',
#    'dislikes': '203',
#    'comment_count': '413'},
#   'thumbnail_link': 'https://i.ytimg.com/vi/7Y3ixg-NBtc/default.jpg',
#   'description': 'REALIZAÇÃO: PLAY9Canal do Felipe - https://www.youtube.com/user/felipenetoCanal do Luccas - https://www.youtube.com/user/luccasnetoCanal do Bruno - https://www.youtube.com/user/PlatinaKHCanal da Bruna - https://www.youtube.com/channel/UCu3PnW9yUmniJj5-QZ44jOQ'},
#  {'video_id': 'JqPZQmNCJf0',
#   'timestamp': '12-31-2019 21:14',
#   'country_code': 'BR',
#   'country_name': 'Brasile',
#   'title': 'BATATA GRATINADA DIFERENTE E FACIL',
#   'publishedAt': '2019-12-31T14:00:03.000Z',
#   'channelId': 'UCKprb2rS223xM5uNsbrSVAg',
#   'channelTitle': 'Tata Pereira',
#   'categoryId': '22',
#   'category_name': 'People & Blogs',
#   'trending_date': '20.01.01',
#   'tags': ['[none]'],
#   'statistics': {'view_count': '24804',
#    'likes': '4092',
#    'dislikes': '77',
#    'comment_count': '58'},
#   'thumbnail_link': 'https://i.ytimg.com/vi/JqPZQmNCJf0/default.jpg',
#   'description': 'Um almoço para você arrasar na sua casa, muito fácil de fazer e rápido, anote os ingredientes e bora começar!!!VÍDEOS NOVOS TODOS OS DIAS ÀS 11:00Ingredientes:2 colheres (sopa) de óleo1/2 cebola picada2 dentes de alho8 batatas cortadas em rodelasPimenta do reino (a gosto)Orégano (a gosto)Sal (a gosto)2 xícaras (chá) de leiteMuçarela (a gosto)♡Para envios de correspondências e entregas:Tata Pereira Caixa Postal:1707Sorocaba SPCEP:18015-970🌻🌻♡ Me siga também:Face:https://goo.gl/bcz89qSite para imprimir: http://tatapereira.com.br/Twitter: http://twixar.me/YJ9KPinterest:http://twixar.me/NJ9K♡ ♡  Muito obrigada meus amores pelo carinho e por assistir. Deixe seu comentário e o joinha pois é muito importante para mim. E não se esqueçam de se INSCREVER no canal e ativar o SININHO DE NOTIFICAÇÕES! ♡♡🌻🌻🌻🌻#tatapereira #receitafacil'},
#  {'video_id': 'GFX5vWoHrXE',
#   'timestamp': '12-31-2019 21:14',
#   'country_code': 'BR',
#   'country_name': 'Brasile',
#   'title': '(SURPREENDEU) SALVADOR (SP) X OSAMA (BA) - FINAL - BATALHA DO COLISEU EDIÇÃO #28',
#   'publishedAt': '2019-12-31T01:09:22.000Z',
#   'channelId': 'UC_Ldk7F5xFUKDo5VhNI5vdg',
#   'channelTitle': 'BDC RJ - Batalha do Coliseu',
#   'categoryId': '10',
#   'category_name': 'Music',
#   'trending_date': '20.01.01',
#   'tags': ['batalha',
#    'do',
#    'coliseu',
#    'rima',
#    'música',
#    'rap',
#    'hip',
#    'hop',
#    'hiphop',
#    'ritmo',
#    'poesia',
#    'cultural',
#    'cultura',
#    'roda',
#    'vila',
#    'isabel',
#    'mc',
#    'rimas',
#    'de',
#    'tanque',
#    'tank',
#    'kgl',
#    'catete',
#    'gloria',
#    'lapa',
#    'meier',
#    'sangue',
#    'zona',
#    'norte',
#    'vs'],
#   'statistics': {'view_count': '78287',
#    'likes': '7638',
#    'dislikes': '80',
#    'comment_count': '377'},
#   'thumbnail_link': 'https://i.ytimg.com/vi/GFX5vWoHrXE/default.jpg',
#   'description': 'Batalha do Coliseu - acontece todas as quartas-feiras no bairro do Méier - a partir das 19:00Visando a volta do Rio de Janeiro ao cenário das batalhas, a batalha do Coliseu foi criada.Instagram: @bdcoliseuSe inscreva no canalAo usar as imagens, favor dar aos créditos.'},
#  {'video_id': 'kUkhZ0jl8m4',
#   'timestamp': '12-31-2019 21:14',
#   'country_code': 'BR',
#   'country_name': 'Brasile',
#   'title': 'FIZ MINHA ROUPA E MAQUIAGEM DOS SONHOS PARA O ANO NOVO | KIM ROSACUCA',
#   'publishedAt': '2019-12-31T00:59:53.000Z',
#   'channelId': 'UCMc-r8lDh-bbN_bhVz8ySEg',
#   'channelTitle': 'Kim RosaCuca',
#   'categoryId': '26',
#   'category_name': 'Howto & Style',
#   'trending_date': '20.01.01',
#   'tags': ['kim', 'carvalho', 'kimrosacuca', 'kimberli', 'kim rosa kuka'],
#   'statistics': {'view_count': '137989',
#    'likes': '18491',
#    'dislikes': '181',
#    'comment_count': '574'},
#   'thumbnail_link': 'https://i.ytimg.com/vi/kUkhZ0jl8m4/default.jpg',
#   'description': 'Aqui nesse  canal tem tudo meu bem! A maquiagem é pra tu fazer junto hein, fácil fácil pra todo mundo brilhar nesse novo ano, e ó, tem novidade, COSTURA vai entrar com tudo nesse canal, então tira a maquina de costura do forno e faça seus pedidos. Beijos de Luz. ME SEGUE AÍ, VAMOS SER AMIGUINHOS ^^🔶 Instagram: https://instagram.com/kimrosacuca🔶 Facebook: http://fb.com/kimrosacuca🔶 Twitter: https://www.twitter.com/kimrosacuca🔶 Pinterest: https://www.pinterest.com/kimrosacuca✅ CONTATO COMERCIAL: comercial@timerosacuca.comVEM PARTICIPAR DO NOSSO CLUBE: https://www.youtube.com/channel/UCMc-r8lDh-bbN_bhVz8ySEg/joinME MANDEM COISINHAS 💛Kimberli CarvalhoRua Pedro Américo, 640 - Apto 115 Curitiba| PRCEP: 81110-010*Músicas utilizadas no vídeo: epidemicsound.com'},
#  {'video_id': 'N59uMR_pDbw',
#   'timestamp': '12-31-2019 21:14',
#   'country_code': 'BR',
#   'country_name': 'Brasile',
#   'title': 'O Que Deu Bom e o Que Deu Ruim em 2019 EP #540',
#   'publishedAt': '2019-12-31T14:00:02.000Z',
#   'channelId': 'UCLXl1V6n82Dyg1VhVgSL0nw',
#   'channelTitle': 'Aviões e Músicas',
#   'categoryId': '28',
#   'category_name': 'Science & Technology',
#   'trending_date': '20.01.01',
#   'tags': ['AVIAÇÃO',
#    'Lito',
#    'Lito do Aviões e Músicas',
#    'AVIÕES E MÚSICAS',
#    'Aerolito',
#    'Airbus',
#    'Boeing',
#    'Embraer',
#    'Airbus 50',
#    'Embraer 50',
#    'Max',
#    'Estatística',
#    'estatística',
#    'Congo',
#    'Bek Air'],
#   'statistics': {'view_count': '44519',
#    'likes': '11672',
#    'dislikes': '52',
#    'comment_count': '651'},
#   'thumbnail_link': 'https://i.ytimg.com/vi/N59uMR_pDbw/default.jpg',
#   'description': 'Retrospectiva 2019 na Aviação. Feliz Ano Novo a todos.✈ Seja Membro: http://bit.ly/ApoiarCanal✈ Loja do Canal: http://bit.ly/CamisetasDoCanal✈ Livro do lito: http://bit.ly/livrosDoLito ✈ Contato Comercial: comercial@avioesemusicas.com✈ Seu vídeo na abertura: http://bit.ly/EnviarSuaSaudacao✈ Escreva para o AeM: Caixa Postal 3008     CEP 07190-972 - Guarulhos/SP==// Mídia Social✈ Twitter: @avioesemusicas✈ Instagram: avioesemusicas✈ Facebook: http://facebook.com/avioesemusicas✈ Aviões e Músicas é um canal para descomplicar a aviação e complementar as informações do blog http://www.avioesemusicas.comVídeos novos toda Quinta e Domingo às 12h00. Ou um Extra a qualquer dia.✈ Vinheta de abertura: Ivo Duran (@ivoduran)Disclaimer: “The views expressed in this video are my own. They have not been reviewed or approved by United. I do not speak for United.”Os pontos de vistas aqui apresentados são apenas meus e não foram revistos ou aprovados pela United. Eu não falo em nome da United.'},
#  {'video_id': '4q0PcpwgNKg',
#   'timestamp': '12-31-2019 21:14',
#   'country_code': 'BR',
#   'country_name': 'Brasile',
#   'title': 'Costelinha Defumada e Molho Barbecue Caseiro no PitSmoker - Smoked Pork Ribs | Netão! Bom Beef #65',
#   'publishedAt': '2019-12-31T14:45:00.000Z',
#   'channelId': 'UCNU_eMfEmoktIhUsuikHNWA',
#   'channelTitle': 'Netão Bom Beef',
#   'categoryId': '24',
#   'category_name': 'Entertainment',
#   'trending_date': '20.01.01',
#   'tags': ['churrasco',
#    'churras',
#    'bbq',
#    'barbecue',
#    'carnivore',
#    'carnes',
#    'carnes especiais',
#    'carnesespeciais',
#    'carne especial',
#    'carne premium',
#    'foodporn',
#    'butcher',
#    'meat',
#    'angus',
#    'delicious',
#    'steak',
#    'parrilla',
#    'netao',
#    'netão',
#    'assado',
#    'bombeef',
#    'perdigão',
#    'costelinha perdigão',
#    'costelinha defumada',
#    'costelinha no pit',
#    'american bbq',
#    'american barbecue',
#    'bom beef',
#    'dry rub',
#    'molho bbq',
#    'molho barbecue',
#    'costelinha suina',
#    'costelinha de porco',
#    'porkribs',
#    'franklinbbq',
#    'perdigao'],
#   'statistics': {'view_count': '40432',
#    'likes': '5144',
#    'dislikes': '40',
#    'comment_count': '155'},
#   'thumbnail_link': 'https://i.ytimg.com/vi/4q0PcpwgNKg/default.jpg',
#   'description': 'Se liga nessa Costelinha Suína Defumada no pit com dry rub e um molho BBQ especial - Pork Ribs with Barbecue Sauce! Típico American Barbecue! Referência Franklin BBQ - Confere aeh! ;)DryRub–\xa01/2 copo de pimenta do reino–\xa01/4 copo de sal de parrilla–\xa03 col. de chá de páprica doce–\xa0pimenta chilli a gosto–\xa01 col. de chá de cebola em pó– 1 col. de chá de alho em póMOLHO BBQ–\xa01 cebola roxa–\xa0100g. de manteiga (+ fio de óleo para a manteiga não queimar)–\xa0pimenta do reino a gosto– 1 col. de chá de pimenta chilli– 2 col. de sopa de shoyu– 2 col. de sopa de molho inglês– 3 col. de sopa de mostarda–\xa01 xic. de chá de molho de tomate– 1/2 xic. de chá de ketchup– 1 col. de chá de alho em pó– 3 col. de sopa de vinagre de maçã– 2 col. de sopa de melWorkshops: www.bombeefsantos.com.brSais , Bonés, Avental by Netão:https://www2.emporiocantagallo.com.br/produtos-netaoCasa de Carnes Bom Beef Santos: Av. Pedro Lessa, 2526 - Santos/SpAh! E não deixe de seguir no Instagram@netaobombeef e@bombeefsantosCaptação: @brunomizogutti Edição: Rodrigo Lelles e @brunomizoguttiDireção: @Netaobombeef e MizoDiretorValeu! Até o próximo!'},
#  {'video_id': 'DNjvOkUetiI',
#   'timestamp': '12-31-2019 21:14',
#   'country_code': 'BR',
#   'country_name': 'Brasile',
#   'title': 'Luxa quer volante do Bahia / Thiago Maia no Fla? / Grêmio não conta com Tardelli / Rodrigão e Mugni',
#   'publishedAt': '2019-12-31T11:25:46.000Z',
#   'channelId': 'UCx0RRbF4EJOUQ28SurIU7Eg',
#   'channelTitle': 'Canal do Nicola',
#   'categoryId': '17',
#   'category_name': 'Sports',
#   'trending_date': '20.01.01',
#   'tags': ['gregore',
#    'gregore bahia',
#    'gregore palmeiras',
#    'gregore luxemburgo',
#    'flamengo',
#    'flamengo thiago maia',
#    'thiago maia',
#    'tardelli',
#    'tardelli grêmio',
#    'tardelli salario',
#    'tardelli saída',
#    'jorge nicola',
#    'canal do nicola',
#    'nicola',
#    'mercado',
#    'mugni sport',
#    'rodrigão ceará',
#    'reforços palmeiras',
#    'reforços flamengo',
#    'reforços grêmio'],
#   'statistics': {'view_count': '115541',
#    'likes': '15572',
#    'dislikes': '213',
#    'comment_count': '622'},
#   'thumbnail_link': 'https://i.ytimg.com/vi/DNjvOkUetiI/default.jpg',
#   'description': 'Depois de indicar Guarín, Vanderlei Luxemburgo pediu à diretoria do Palmeiras a contratação do volante Gregore, do Bahia.Já a negociação entre Flamengo e Lille por Thiago Maia passa por um momento mais turbulento, como eu explico no vídeo.E toda a diretoria do Grêmio está na torcida para Tardelli encontrar um clube, para se livrar do custo de R$ 1 milhão por mês com o atacante.Por fim, detalhes sobre os acertos de Rodrigão com o Ceará e Lucas Mugni com o Sport.Link do vídeo:https://youtu.be/DNjvOkUetiI'},
#  {'video_id': 'tuvGCITKaGU',
#   'timestamp': '12-31-2019 21:14',
#   'country_code': 'BR',
#   'country_name': 'Brasile',
#   'title': 'TRAKKER PAI DO HI WAY | NENI AO EXTREMO - Ep.03',
#   'publishedAt': '2019-12-30T23:46:44.000Z',
#   'channelId': 'UCP78dbFMqqu6PeBbFl5U4_Q',
#   'channelTitle': 'CLAUDEMIR GIGLIOTTI',
#   'categoryId': '22',
#   'category_name': 'People & Blogs',
#   'trending_date': '20.01.01',
#   'tags': ['[none]'],
#   'statistics': {'view_count': '99514',
#    'likes': '18907',
#    'dislikes': '132',
#    'comment_count': '407'},
#   'thumbnail_link': 'https://i.ytimg.com/vi/tuvGCITKaGU/default.jpg',
#   'description': '✓ Facebook: https://www.facebook.com/CanaldoNeNiOficial/✓ Meu Instagram: https://www.instagram.com/claudemirgigliotti_neni/♦ Contato comercial: comercial@canaldoneni.com.br✔ Site Oficial: www.canaldoneni.com.brAcesse: https://jvacessorios.com.br/Tracker:  0300 400 5000#Canaldoneni #vidadecaminhoneiro #caminhoneiro'},
#  {'video_id': 'TfMPfTWuaac',
#   'timestamp': '12-31-2019 21:14',
#   'country_code': 'BR',
#   'country_name': 'Brasile',
#   'title': 'QUEM CUSTOMIZA MELHOR O TÊNIS !!!',
#   'publishedAt': '2019-12-30T22:10:14.000Z',
#   'channelId': 'UCvuJTWl_peL49CUfF2EAbyg',
#   'channelTitle': 'Camila Loures',
#   'categoryId': '24',
#   'category_name': 'Entertainment',
#   'trending_date': '20.01.01',
#   'tags': ['camila', 'loures', 'QUEM CUSTOMIZA MELHOR O TÊNIS !!!'],
#   'statistics': {'view_count': '305196',
#    'likes': '44837',
#    'dislikes': '472',
#    'comment_count': '3235'},
#   'thumbnail_link': 'https://i.ytimg.com/vi/TfMPfTWuaac/default.jpg',
#   'description': 'LINK DO LIVRÃO CAMILA LOURES : https://www.camilaloureslivros.com.br/index.php?route=product/product&product_id=1MOSTRA ESSE CANAL PRA ALGUEM, UM DIA TEREMOS 50 MILHÕES DE INSCRITOS!! SEJA MEMBRO AQUI DO CANALhttps://www.youtube.com/channel/UCvuJTWl_peL49CUfF2EAbyg/joinCANAL DO PH LOURES: https://www.youtube.com/user/phlouresINSTAGRAM: https://www.instagram.com/camilaloures/?hl=ptTWITTER:  https://twitter.com/camilaloures?lang=ptPERFIL NO FACEBOOK: https://www.facebook.com/camila.loures.9EMAIL PARA CONTATO: contatocamilaloures@gmail.com'},
#  {'video_id': 'ljaVqUgZLaA',
#   'timestamp': '12-31-2019 21:14',
#   'country_code': 'BR',
#   'country_name': 'Brasile',
#   'title': 'ARGENTINO JULIO BUFFARINI DO BOCA JRS INTERESSA | SALÁRIOS | Últimas Notícias do Vasco da Gama',
#   'publishedAt': '2019-12-31T08:30:11.000Z',
#   'channelId': 'UCUzrTcQHWjvIF_XYTstdlbw',
#   'channelTitle': 'Mario Coelho Vasco',
#   'categoryId': '17',
#   'category_name': 'Sports',
#   'trending_date': '20.01.01',
#   'tags': ['canal do vasco',
#    'globo esporte vasco',
#    'informacoes do vasco',
#    'mario coelho',
#    'mario coelho vasco',
#    'noticias do vascao',
#    'noticias do vasco',
#    'noticias do vasco com mario coelho',
#    'notícias do vasco da gama',
#    'noticias do vasco globo esporte',
#    'noticias do vasco hoje',
#    'novidades do vasco',
#    'ultimas noticias do vasco',
#    'vasco',
#    'vasco da gama hoje',
#    'vasco da gama noticias',
#    'vasco hoje',
#    'vasco noticias hoje',
#    'vasco reforços',
#    'REFORÇOS DO VASCO 2020',
#    'GERMAN CANO NO VASCO',
#    'GERMAN CANO',
#    'dede no vasco'],
#   'statistics': {'view_count': '50863',
#    'likes': '9291',
#    'dislikes': '143',
#    'comment_count': '493'},
#   'thumbnail_link': 'https://i.ytimg.com/vi/ljaVqUgZLaA/default.jpg',
#   'description': '●  JULIO BUFFARINI DO BOCA JR INTERESSA E SALÁRIOS SEGUEM ATRASADOS | Últimas Notícias do Vasco da Gama✅ VIRE MEMBRO DO CANAL E PARTICIPE DO SORTEIO DE 6 CAMISAS OFICIAIS DO VASCO POR SEMANA:CLIQUE NO LINK ABAIXO:https://www.youtube.com/channel/UCUzrTcQHWjvIF_XYTstdlbw/join✅ INSTAGRAM  https://www.instagram.com/mariocoelhovasco/● CONTRATAÇÕES, REFORÇOS, DISPENSA DE JOGADORES E PATROCÍNIO PRO VASCO EM 2020● Últimas Notícias do Vasco da Gama ● Informações do Vasco da Gama ● Novidades do Vasco da Gama ● Canal Mario Coelho Vasco● VIRE MEMBRO DO CANAL https://www.youtube.com/channel/UCUzrTcQHWjvIF_XYTstdlbw/join● LOJA COM PRODUTOS OFICIAIS DO CANAL:https://www.colab55.com/@mariocoelhovascVIRE SÓCIO DO VASCO: www.sociogigante.com-—Redes Sociais—✅VIRE MEMBRO DO CANAL E PARTICIPE DO SORTEIO DE 6 CAMISAS OFICIAIS DO VASCO POR SEMANA:CLIQUE NO LINK ABAIXO:https://www.youtube.com/channel/UCUzrTcQHWjvIF_XYTstdlbw/join✅ INSTAGRAM  https://www.instagram.com/mariocoelhovasco/✅ TWITTER https://twitter.com/mariocoelhovasc✅ FACEBOOK PAGINA https://www.facebook.com/mariocoelhovasco/✅ GRUPO TELEGRAM: https://t.me/mariocoelhovascocanal✅ *NAVEGADOR BRAVE* INSTALE NO LINK: https://brave.com/ict266✅ FACEBOOK GRUPO https://www.facebook.com/groups/1871209516241158/manoel serafin rubens percival********************************************************************************************************Email De Contato do Canal para anúncios e parcerias : canalmariocoelhovasco@gmail.com*********************************************************************************************************PATROCINADORES E PARCEIROS DO CANAL:✅INSTAGRAM EMPRESA DE EVENTOS EQUIPE1O:https://www.instagram.com/EQUIPE10PROMO/✅ R$ 5 REAIS DE PRESENTE E O DOBRO NO PRIMEIRO DEPÓSITO PARA JOGADR NA NETBET: http://nbet.co/mariocoelho✅ *INSCREVA-SE NO CANAL* Futebol & Papo Furado: https://www.youtube.com/c/PapoFuradocanal✅ *NAVEGADOR BRAVE* INSTALE NO LINK: https://brave.com/ict266✅ *R$179 DE PRESENTE DO CANA NO AIRBNB* - https://www.airbnb.com.au/c/marioc5938?currency=BRL'},
#  {'video_id': 'LGMkn5L6ZN4',
#   'timestamp': '12-31-2019 21:14',
#   'country_code': 'BR',
#   'country_name': 'Brasile',
#   'title': "FLAMENGO: DIEGO AMEAÇA A TITULARIDADE DE GERSON? Assunto gera debate no 'Expediente Futebol'",
#   'publishedAt': '2019-12-30T21:42:16.000Z',
#   'channelId': 'UCw5-xj3AKqEizC7MvHaIPqA',
#   'channelTitle': 'FOX Sports Brasil',
#   'categoryId': '17',
#   'category_name': 'Sports',
#   'trending_date': '20.01.01',
#   'tags': ['FOX',
#    'FOX Sports',
#    'FX',
#    'FOX Sports Brasil',
#    'Futebol',
#    'Soccer',
#    'Football',
#    'Brasil',
#    'Brasileirão',
#    'Campeonato Brasileiro',
#    'BRA',
#    'Brazil',
#    'Copa do Brasil',
#    'Libertadores',
#    'Rodada',
#    'Gols da Rodada',
#    'Melhores Momentos',
#    'Esporte',
#    'FUT',
#    'FOX AO VIVO',
#    'Ao Vivo',
#    'Rádio',
#    'Flamengo',
#    'Palmeiras',
#    'Corinthians',
#    'Neymar',
#    'Rubro-negro',
#    'Carlos Alberto',
#    'Coutinho',
#    'Felipe',
#    'Phillipe',
#    'Philippe',
#    'Goal',
#    'Gabigol',
#    'Timão',
#    'Barcelona',
#    'Real Madrid',
#    'Benja'],
#   'statistics': {'view_count': '85519',
#    'likes': '2584',
#    'dislikes': '99',
#    'comment_count': '366'},
#   'thumbnail_link': 'https://i.ytimg.com/vi/LGMkn5L6ZN4/default.jpg',
#   'description': 'Assunto gerou debate no programa e nossos comentaristas deram suas opiniões. Qual a sua, torcedor?Quer saber tudo sobre o melhor do esporte? Acesse nossas redes!http://www.foxsports.com.br➡ Facebook: http://facebook.com/foxsportsbrasil ➡ Twitter: http://twitter.com/foxsportsbrasil➡ Instagram: http://instagram.com/foxsportsbrasilTorcemos Juntos!#Flamengo #Diego #Gerson'},
#  {'video_id': 'VkVKKCmJ_c4',
#   'timestamp': '12-31-2019 21:14',
#   'country_code': 'BR',
#   'country_name': 'Brasile',
#   'title': 'ÁREA VIP',
#   'publishedAt': '2019-12-30T14:00:07.000Z',
#   'channelId': 'UCEWHPFNilsT0IfQfutVzsag',
#   'channelTitle': 'Porta dos Fundos',
#   'categoryId': '24',
#   'category_name': 'Entertainment',
#   'trending_date': '20.01.01',
#   'tags': ['porta dos fundos',
#    'kibe loco',
#    'fabio porchat',
#    'gregorio duviver',
#    'ian sbf',
#    'antonio tabet',
#    'joão vicente de castro',
#    'comedia',
#    'humor',
#    'engraçado',
#    'funny',
#    'comedy',
#    'risos',
#    'risadas',
#    'hilario',
#    'bizarro',
#    'parodia',
#    'satira',
#    'cotidiano',
#    'o limite do humor',
#    'balada',
#    'night',
#    'cerveja',
#    'bebida',
#    'festa',
#    'rei do camarote',
#    'camarote',
#    'bebida que pisca',
#    'exclusividade',
#    'VIP',
#    'fila'],
#   'statistics': {'view_count': '561104',
#    'likes': '73955',
#    'dislikes': '2841',
#    'comment_count': '954'},
#   'thumbnail_link': 'https://i.ytimg.com/vi/VkVKKCmJ_c4/default.jpg',
#   'description': 'Sabe aquele festival de rock super bombado? No próximo eu vou de Àrea Vipíssima. Tem cerveja à vontade, é só pegar numa geladeirona que tem lá. Comida e salgadinho à disposição. O banheiro é privativo, limpinho, só eu posso usar. Pra sentar, um sofá top bem confortável, com uma inovação: um cachorro pra ficar perto todo bonitinho. O show eu vou ver de um telão exclusivo, ninguém passa na frente nem fica cantando mal do meu lado. Qualidade 4k e som surround. Só tem uns intervalos comerciais às vezes e uns apresentadores que falam umas informações aleatórias, tipo que o vocalista da banda tal colocou tal coisa no Instagram e brigou com o outro. Normal. Como o espaço é isolado, não preciso me preocupar com a Anitta querendo tirar foto comigo. E se estiver calor, rola uma climatização com ventilador de teto, coisa fina. E o melhor: zero filas e zero deslocamento da minha casa.ELENCOGregório DuvivierPedro BenevidesMAKING OF: https://youtu.be/Df8m_dd2lKUBAIXE O APP DO PORTAAndroid: http://bit.ly/2zcxLZOiOS: https://apple.co/2IW633jTRADUÇÃO E LEGENDAGEMDispositivaJosniel RodriguezEsse é o canal Porta dos Fundos. Lançamos vídeos todas as segundas, quintas e sábados às 11h.'},
#  {'video_id': 'nIl6hE4eACQ',
#   'timestamp': '12-31-2019 21:14',
#   'country_code': 'BR',
#   'country_name': 'Brasile',
#   'title': 'AS NOVAS RODAS 😍',
#   'publishedAt': '2019-12-30T15:00:09.000Z',
#   'channelId': 'UCnvxs-wKQXlP1gDK49nZCLg',
#   'channelTitle': 'Saveiro do RAU',
#   'categoryId': '2',
#   'category_name': 'Autos & Vehicles',
#   'trending_date': '20.01.01',
#   'tags': ['saveiro do rau',
#    'rau',
#    'rauan',
#    'caminhão',
#    '1620',
#    'sapecado',
#    'reforma',
#    'nova',
#    'cor',
#    'das rodas',
#    'rodas pintadas',
#    'moda',
#    'traseira alta',
#    'frente baixa',
#    'traseira arqueada',
#    'caminhoneiro',
#    'pintura',
#    'VERDUREIRO',
#    'flogueiro',
#    'gbn',
#    'gang'],
#   'statistics': {'view_count': '194519',
#    'likes': '30012',
#    'dislikes': '271',
#    'comment_count': '1721'},
#   'thumbnail_link': 'https://i.ytimg.com/vi/nIl6hE4eACQ/default.jpg',
#   'description': 'A nova cor das rodas dianteiras 😍Olha como ficou hehe Tirando o radiador pra arrumar também Inscreva-se no canal 👉 https://goo.gl/sFSYhl👇🏻Caixa postal 003Alto Paraná - PRCEP 87750-000Curta nossa página no facebook 👉 https://goo.gl/tblyPu Me siga no Instagram 👉 https://www.instagram.com/rau_rauan/'},
#  {'video_id': 'qjOm650N8RI',
#   'timestamp': '12-31-2019 21:14',
#   'country_code': 'BR',
#   'country_name': 'Brasile',
#   'title': 'BABY SONIC e o NOVO controle do PLAYSTATION 5',
#   'publishedAt': '2019-12-30T21:00:08.000Z',
#   'channelId': 'UCJAbkIY17zAmCTNQHH0bQoQ',
#   'channelTitle': 'Gameplayrj',
#   'categoryId': '20',
#   'category_name': 'Gaming',
#   'trending_date': '20.01.01',
#   'tags': ['gameplayrj',
#    'davyjones',
#    'davy jones',
#    'video com davy jones',
#    'jogando com davy jones',
# ...
#  {'video_id': '-CxU68SfZMg',
#   'timestamp': '12-31-2019 23:15',
#   'country_code': 'BR',
#   'country_name': 'Brasile',
#   'title': 'O TRISTE FIM DO CASAL MAURIN',
#   'publishedAt': '2019-12-20T00:24:44.000Z',
#   'channelId': 'UCU20zn5IueQz8WAfud-oeFw',
#   'channelTitle': 'Jaqueline Guerreiro',
#   'categoryId': '22',
#   'category_name': 'People & Blogs',
#   'trending_date': '20.01.01',
#   'tags': ['jacguerreiro18',
#    'quinta misteriosa',
#    'caso',
#    'solucionado',
#    'investigação',
#    'maurin',
#    'minnie',
#    'ed',
#    'hadaller',
#    'natal',
#    'caso no natal',
#    'tudo sobre',
#    'como foi',
#    'o que aconteceu',
#    'triste fim',
#    'casal'],
#   'statistics': {'view_count': '397012',
#    'likes': '57599',
#    'dislikes': '296',
#    'comment_count': '1647'},
#   'thumbnail_link': 'https://i.ytimg.com/vi/-CxU68SfZMg/default.jpg',
#   'description': 'Playlist Quinta Misteriosa: https://goo.gl/r9BvxR\rPlaylist Teorias: http://bit.ly/2EzFGAy\r\r► SE INSCREVA! https://goo.gl/kvo4Sz\rhttps://www.instagram.com/jaccguerreiro\rhttps://www.facebook.com/JacGuerreiro/\rhttps://www.Twitter.com/jaccguerreiro\r\r► ► ►  Contato ◄ ◄ ◄ \rCONTATO PROFISSIONAL:  jaqueline@dafatos.com.br'},
#  {'video_id': 'VRq8aDx1e4w',
#   'timestamp': '12-31-2019 23:15',
#   'country_code': 'BR',
#   'country_name': 'Brasile',
#   'title': 'EM BUSCA DO RAMEN PERFEITO: RAMEN BUNITINHO - Japão Nosso De Cada Dia',
#   'publishedAt': '2019-12-20T15:00:05.000Z',
#   'channelId': 'UCiLb0XHjvUs7t1LUFMXpifQ',
#   'channelTitle': 'Japão Nosso De Cada Dia',
#   'categoryId': '24',
#   'category_name': 'Entertainment',
#   'trending_date': '20.01.01',
#   'tags': ['Japão',
#    'Japão Nosso De Cada Dia',
#    'Lohgann',
#    'Prit',
#    'Será que isso funciona?',
#    'vida no Japão',
#    'dicas do Japão',
#    'doces do Japão',
#    'comidas do Japão',
#    'curiosidades do Japão',
#    'esquisitices do Japão',
#    'novidades do Japão',
#    'produtos do japão',
#    'turismo no Japão',
#    'morar no Japão',
#    'trabalhar no japão',
#    'sabores do japão',
#    'cultura do japão',
#    'português',
#    'brasil',
#    'br',
#    'pt',
#    'ptbr',
#    'jndcd',
#    'ramen',
#    'lamen',
#    'ramen perfeito',
#    'em busca do ramen perfeito',
#    'ramen mediano'],
#   'statistics': {'view_count': '162016',
#    'likes': '21564',
#    'dislikes': '147',
#    'comment_count': '587'},
#   'thumbnail_link': 'https://i.ytimg.com/vi/VRq8aDx1e4w/default.jpg',
#   'description': '🍞 CAMISETAS OFICIAIS JNDCD: http://bit.ly/JapanSocietyJNDCD\rCUPOM DE DESCONTO: JNDCD10\r🍞 Seja Membro do Canal: http://bit.ly/JNDCDmembro\r\r🍞 Facebook: http://bit.ly/facebookJNDCD\r\r🍞 Site Japão Nosso De Cada Dia: http://bit.ly/siteJNDCD\r\r🍞 Instragram da Prit: http://bit.ly/instaPRIT\r🍞 Twitter da Prit: http://bit.ly/TwTPRIT\r\r🍞 Instagram do Lohgann: http://bit.ly/instaLOHGANN\r🍞 Twitter do Lohgann: http://bit.ly/TwTLOHGANN\r\r🦒 Canal da Prit: http://bit.ly/MeuDiaComum\r\r🕹️ Canal do Lohgann: http://bit.ly/EueElaJoga\r\r🎶Music\rby Milton Paredes: Good Morning Tokyo\rby Youtube (Estúdio de Criação)\rby http://soundbible.com/\rby http://on-jin.com/\r\r#EMBUSCADORAMENPERFEITO'},
#  {'video_id': '1EjGhoP44fY',
#   'timestamp': '12-31-2019 23:15',
#   'country_code': 'BR',
#   'country_name': 'Brasile',
#   'title': 'PERU PERFEITO COM FAROFA E SALADA DE MAIONESE | Receitas de Natal | Mohamad Hindi',
#   'publishedAt': '2019-12-19T23:00:01.000Z',
#   'channelId': 'UC92stP3p40WmY-6-8X14zbQ',
#   'channelTitle': 'Mohamad Hindi',
#   'categoryId': '24',
#   'category_name': 'Entertainment',
#   'trending_date': '20.01.01',
#   'tags': ['mohamad',
#    'mohamed',
#    'masterchef',
#    'comida',
#    'gastronomia',
#    'receita',
#    'receitas',
#    'morramed',
#    'morramad',
#    'mohindi',
#    'hindi',
#    'como preparar',
#    'como temperar',
#    'assado',
#    'forno',
#    'como assar',
#    'temperado',
#    'molho',
#    'natal',
#    'natalino',
#    'natalina',
#    'ceia',
#    'cadápio de natal',
#    'almoço de natal simples e gostoso',
#    'almoço',
#    'jantar',
#    'peru',
#    'temperar',
#    'culinaria',
#    'comidas',
#    'sadia',
#    'recheado',
#    'farofa',
#    'maionese',
#    'batatas',
#    'salada',
#    'leite',
#    'caseiro',
#    'temperada',
#    'fria',
#    'cenoura',
#    'como fazer',
#    'como faz',
#    'como se faz',
#    'descongelar',
#    'tempero',
#    'temperando',
#    'assar',
#    'ave',
#    'suculento',
#    'coxa',
#    'vinho',
#    'manteiga',
#    'bacon'],
#   'statistics': {'view_count': '336929',
#    'likes': '26599',
#    'dislikes': '273',
#    'comment_count': '1156'},
#   'thumbnail_link': 'https://i.ytimg.com/vi/1EjGhoP44fY/default.jpg',
#   'description': 'Aprenda como preparar, temperar e assar um peru Sadia no forno com molho para a ceia de Natal com farofa de bacon e salada de maionese e batatas. Essa receita é perfeita para comer com as pessoas que você ama e celebrar! ;)Inscreva-se no canal: http://bit.ly/1UZJwqk INGREDIENTES:Peru SadiaSalviaAlecrimTomilhoLavandaManteigaPimenta-do-reino pretaSalRaspas de laranjaLimão sicilianoAlhoAzeiteCebolaCenouraSalsãoAlho-poróVinho branco seco(Molho para pincelar)2 Colheres de sopa de melaço de cana1/2 Copo de vinagre de vinho brancoAlecrimTomilhoCasca de laranjaBarbante100g Manteiga sem sal(Salada de batata)Batata bolinhaAzeiteAlho-poróCebolaCenouraSalPimenta-do-reino pretaPicles de cebola roxaMaionese de leiteLimãoMostarda dijonSalsinhaCebolinha(Farofa de miúdos)Castanha de cajuAvelãAmendoimNozesCastanha do ParáUva passa brancaUva passa pretaFígado de peruCoração de peruAzeiteSalBaconManteigaFarinha de mandiocaEspumante ou vinho branco para hidratar as uvas passasSalsinhaCebolinhaRedes Sociais: http://www.facebook.com/mohindi http://www.instagram.com/mohindi http://www.twitter.com/mohindi mohindi87@gmail.comVÍDEOS TODAS AS TERÇAS E QUINTAS-FEIRAS ÀS 20H E DOMINGO ÀS 18H.Equipe: Direção: Rafael Ribas Filmagem: Rafael Ribas e Bruno FiorioSom: Will InácioProdução: Will Inácio, Maryan Hindi e Flávia ZündtEdição: Marina Alves'},
#  {'video_id': '-cX5TtNqn7s',
#   'timestamp': '12-31-2019 23:15',
#   'country_code': 'BR',
#   'country_name': 'Brasile',
#   'title': 'Jogo de xícaras? Sabrina Sato surpreende no presente para Camila Rodrigues',
#   'publishedAt': '2019-12-20T04:13:33.000Z',
#   'channelId': 'UCu_a6PAzp30Bn2mM-Ll09LA',
#   'channelTitle': 'RECORD TV',
#   'categoryId': '25',
#   'category_name': 'News & Politics',
#   'trending_date': '20.01.01',
#   'tags': ['record', 'tv', 'record tv', 'rede record', 'família record'],
#   'statistics': {'view_count': '375578',
#    'likes': '5663',
#    'dislikes': '205',
#    'comment_count': '341'},
#   'thumbnail_link': 'https://i.ytimg.com/vi/-cX5TtNqn7s/default.jpg',
#   'description': 'Quando a Topíssima Camila Rodrigues abriu o pacote com um jogo de xícaras, teve gente que não acreditou. Mas era só uma brincadeira de Sabrina, que mandou fazer uma linda joia para a atriz. Inscreva-se no canal Record TV:   http://r7.com/BXRa Assista às íntegras no PlayPlus:   https://www.playplus.comFacebook:   https://www.facebook.com/recordtvoficial/Instagram:   https://www.instagram.com/recordtvoficial/ Twitter:   https://twitter.com/recordtvoficialSite oficial:  https://recordtv.r7.com/#RecordTV #FamíliaRecord'},
#  {'video_id': 'Bf7XLhvVr8I',
#   'timestamp': '12-31-2019 23:15',
#   'country_code': 'BR',
#   'country_name': 'Brasile',
#   'title': 'COMPRAS INÚTEIS PARA A CASA NOVA - Ep. 1415',
#   'publishedAt': '2019-12-20T00:32:14.000Z',
#   'channelId': 'UCtrjFP7i92_30uv6IehwE5Q',
#   'channelTitle': 'Cadê a chave?',
#   'categoryId': '24',
#   'category_name': 'Entertainment',
#   'trending_date': '20.01.01',
#   'tags': ['Leon',
#    'Martins',
#    'Nilce',
#    'Moretto',
#    'nilmoretto',
#    'leon',
#    'intercambio',
#    'intercâmbio',
#    'imigrar',
#    'br',
#    'pt',
#    'ptbr',
#    'canada',
#    'teste supremo',
#    'pular corda',
#    'fitness',
#    'exercício',
#    'como queimar caloria',
#    'como descascar ovo ?',
#    'como fatiar ovo?',
#    'como cozinhar ovos?',
#    'Como pular corda?',
#    'Como manter a forma pulando corda?',
#    'como manter a forma sem sair de casa?'],
#   'statistics': {'view_count': '646228',
#    'likes': '97544',
#    'dislikes': '459',
#    'comment_count': '3146'},
#   'thumbnail_link': 'https://i.ytimg.com/vi/Bf7XLhvVr8I/default.jpg',
#   'description': 'Camisas Coisa de Nerd  http://bit.ly/2arsmPrDas coisas mais inúteis que a Nilce poderia comprar, qual dessas é a que menos utilidade tem? O vídeo de hoje é para mostrar novas aquisições e novas metas atléticas para 2020. Pegue o jantar e venha se deliciar conosco com ovos cozidos, descascados com um instrumento próprio e fatiados num  Egg Slicer profissional, mas não tão profissional quanto a corda de pular corda da Nilce. #presentes #utilidades #testesupremo FACEBOOK do CAC: https://facebook.com/kdchaveInstagram do Leon: https://instagram.com/cdnleonCanal CoisadeNerd (GAMES) https://youtube.com/coisadenerdFacebook do Leon: https://facebook.com/coisadenerdTwitter da Nilce: https://twitter.com/nilmorettoInstagram da Nilce:  https://instagram.com/nilmorettoMusic by: Epidemic Sound www.epidemicsound.comYoutube (Ferramentas de Criação) Pacote Royalty Free do Sony Vegas'},
#  {'video_id': 'DOIbt3jkzB8',
#   'timestamp': '12-31-2019 23:15',
#   'country_code': 'BR',
#   'country_name': 'Brasile',
#   'title': 'Maiara e Maraisa - Pot Pourri - EP Aqui Em Casa',
#   'publishedAt': '2019-12-19T14:00:02.000Z',
#   'channelId': 'UCULzCZWkkOb9dW8rr6dguQQ',
#   'channelTitle': 'Maiara e Maraisa',
#   'categoryId': '10',
#   'category_name': 'Music',
#   'trending_date': '20.01.01',
#   'tags': ['maiara e maraisa',
#    'sentimento seu nenhum',
#    'nem tchum letra',
#    'te amo e vc nem tchum',
#    'nem tchum',
#    'maiara e maraisa 2019',
#    'medo bobo',
#    'marilia mendonça',
#    'trai sim maiara e maraisa',
#    'mayara e maraysa',
#    'quer ficar com ela fica',
#    'oi tchau',
#    'sertanejo 2019',
#    'separada maiara e maraisa',
#    'se olha no espelho',
#    'cristiano araujo',
#    'sertanejo',
#    'aí eu bebo',
#    'ai eu bebo',
#    'marilia mendonça 2019',
#    'nao abro mao',
#    'no dia do seu casamento',
#    'naiara azevedo',
#    'workshow',
#    'feminejo',
#    'ep é de casa'],
#   'statistics': {'view_count': '940482',
#    'likes': '19267',
#    'dislikes': '402',
#    'comment_count': '503'},
#   'thumbnail_link': 'https://i.ytimg.com/vi/DOIbt3jkzB8/default.jpg',
#   'description': 'INSCREVA-SE NO NOSSO CANAL: https://goo.gl/8rlBhZ Para shows: (62) 3241-7163 / (62) 9 9109-9766comercial@maiaraemaraisa.com.br#MaiaraeMaraisaOuça ou baixe  Pot Pourri (Cheiro de Shampoo/ Sou Eu/ Sonho por Sonho/ Cara ou Coroa)👉 Youtube Music: https://music.youtube.com/watch?v=L_l-QfCAz9I&list=OLAK5uy_kmHmsn9teQBy_J3XWInkAADawKmFID70k👉 Spotify: https://open.spotify.com/album/3cGq5C2ON2vPyTMvKGUF6E👉 Deezer: https://www.deezer.com/br/album/121338382?app_id=140685&utm_source=lf&utm_content=e9571ac04b4306a6495cba71dff66d24👉 Apple Music: https://music.apple.com/br/album/1490020174?app=music&lId=1801080&cId=none&src=Linkfire&sr=3&ign-itsct=catchall_p3&ign-itscg=30440&ign-mpt=uo%3D4👉 Amazon Music: https://music.amazon.com.br/albums/B08286CGP6👉 Tidal: https://tidal.com/browse/track/124208533👉 Napster: https://br.napster.com/artist/maiara-and-maraisa/album/pot-pourri-cheiro-de-shampoo-sou-eu-entre-ela-e-eu-sonhoOuça ou baixe o álbum REFLEXO: https://SomLivre.lnk.to/Reflexo_Ao_VivoPot Pourri (Cheiro de Shampoo/ Sou Eu/ Sonho por Sonho/ Cara ou Coroa) [ Letra ]Cheiro de Shampoo (Cecilio Nena) Esse amor molhadoFaz tudo acontecerVocê me deixa atiçadoPra te dar mais prazerEu cubro com espumasO seu corpo nuNós dois de baixo do chuveiroAmor com cheiro de shampoo**Sou Eu (Carlos Pedro/ Ed Wilson) Ele te provoca pra mostrar que é melhor que euJoga todo o charme que puder pra ver se me venceuOlha pra você com aquele jeito de quem vai te amarMas do que eu, mais do que euQuando o telefone toca você já não quer atenderPode ser ele do outro lado pra falar com vocêNão sou euAcho que é melhor você contar pra ele de uma vezQue esse amor é todo meu e eu não divido por trêsSou eu, sou euSou eu quem faz amor com você à noiteSou eu quem dá a vida se preciso forFaz ele ver que o seu grande amorSou eu, sou eu, sou eu, sou eu, sou eu**Sonhos por sonho (Carlos Colla/ Chico Roque) Nunca imaginei que você quisesse de mimUma noite só de prazer, uma transa apenasTudo que você me falou, dói no meu coraçãoLoucura cheia de sedução, mudou a minha vidaNão dá pra esquecer a emoção que eu senti com vocêPor tudo que não pode ser, eu te queroEu não tenho tempo a perder com a solidãoNa hora que você me quiser, eu vouBeijo por beijo, sonho por sonhoCarinho por amor, paixão por paixão**Cara ou Coroa (Carlos Colla/ Alejandro/ Carlos Villa) Cara ou coroa, meu amigoVamos jogarÉ tudo ou nada, precisamos decidirÉ pra você ou para mimE pra ninguém maisCara ou coroa, meu amigoVamos jogar'},
#  ...]

# %% [markdown]
# Crea un dizionario in cui inserisce il nome del paese e l'orario di rilevazione della presa dati.

# %%
c_data = {}
for e in j_file:
    t = e["timestamp"]
    c = e["country_name"]
    if c not in c_data.keys(): #se non ho già inserito il country
        c_data[c] = [t]
    else:
        if t not in c_data[c] : #se non ho già inserito questa data in quel country
            c_data[c].append(t)
# Out:
# dict

# %% [markdown]
# Facciamo stampare le rilevazioni del Regno Unito, questa operazione è necessaria in quanto per ogni file bisogna scegliere manualmente le 4 prese dati da tenere. E' un'operazione necessaria in quanto per ogni file i minuti della rilevazione differiscono e nulla ci assicura che l'orario coincida in due file diversi.

# %%
c_data["Regno Unito"]
# Out:
# ['01-01-2020 00:14',
#  '01-01-2020 00:44',
#  '01-01-2020 01:15',
#  '01-01-2020 01:45',
#  '01-01-2020 02:15',
#  '01-01-2020 02:46',
#  '01-01-2020 03:16',
#  '01-01-2020 03:46',
#  '01-01-2020 04:16',
#  '01-01-2020 04:47',
#  '01-01-2020 05:17',
#  '01-01-2020 05:47',
#  '01-01-2020 06:18',
#  '01-01-2020 06:48',
#  '01-01-2020 07:18',
#  '01-01-2020 07:49',
#  '01-01-2020 08:19',
#  '01-01-2020 08:49',
#  '01-01-2020 09:19',
#  '01-01-2020 09:50',
#  '01-01-2020 10:20',
#  '01-01-2020 10:50',
#  '01-01-2020 11:21',
#  '01-01-2020 11:51',
#  '01-01-2020 12:21',
#  '01-01-2020 12:52',
#  '01-01-2020 13:22',
#  '01-01-2020 13:52',
#  '01-01-2020 14:23',
#  '01-01-2020 14:53',
#  '01-01-2020 15:26',
#  '01-01-2020 17:14',
#  '01-01-2020 17:44',
#  '01-01-2020 18:14',
#  '01-01-2020 18:45',
#  '01-01-2020 19:15',
#  '01-01-2020 19:45',
#  '01-01-2020 20:16',
#  '01-01-2020 20:46',
#  '01-01-2020 21:16',
#  '01-01-2020 21:49',
#  '01-01-2020 22:20',
#  '01-01-2020 22:50',
#  '01-01-2020 23:20',
#  '01-01-2020 23:51']

# %% [markdown]
# Scegliamo a questo punto manualmente 4 rilevazioni orarie tra le precedenti in modo che siano staccate di circa 6h:
# - 01-01-2020 04:16
# - 01-01-2020 10:20
# - 01-01-2020 17:14
# - 01-01-2020 22:50
#
# A questo punto iniziamo a tenere solo quelle rilevazioni per il Regno Unito.

# %%
d = [datetime.strptime("01-01-2020 04:16", "%m-%d-%Y %H:%M"),
     datetime.strptime("01-01-2020 10:20", "%m-%d-%Y %H:%M"),
     datetime.strptime("01-01-2020 17:14", "%m-%d-%Y %H:%M"),
     datetime.strptime("01-01-2020 22:50", "%m-%d-%Y %H:%M"),]
times = pd.DataFrame(data = d, columns = ["Regno Unito"])
times
# Out:
#           Regno Unito
# 0 2020-01-01 04:16:00
# 1 2020-01-01 10:20:00
# 2 2020-01-01 17:14:00
# 3 2020-01-01 22:50:00

# %% [markdown]
# Prendiamo anche negli altri paesi le rilevazioni che corrispondono a quelle del regno unito a meno del loro fuso orario.

# %%
for c in country: #per ogni paese
    if c != "GB":
        times[country[c]["name"]] = find_timestamp(times["Regno Unito"], c, country)
times["Regno Unito"] = times["Regno Unito"].apply(datetime.strftime, format = "%m-%d-%Y %H:%M")
times
# Out:
#         Regno Unito               USA             India          Germania  \
# 0  01-01-2020 04:16  12-31-2019 23:16  01-01-2020 09:16  01-01-2020 05:16
# 1  01-01-2020 10:20  01-01-2020 05:20  01-01-2020 15:20  01-01-2020 11:20
# 2  01-01-2020 17:14  01-01-2020 12:14  01-01-2020 22:14  01-01-2020 18:14
# 3  01-01-2020 22:50  01-01-2020 17:50  01-02-2020 03:50  01-01-2020 23:50
#
#              Canada           Francia     Corea del sud            Russia  \
# 0  12-31-2019 23:16  01-01-2020 05:16  01-01-2020 13:16  01-01-2020 07:16
# 1  01-01-2020 05:20  01-01-2020 11:20  01-01-2020 19:20  01-01-2020 13:20
# 2  01-01-2020 12:14  01-01-2020 18:14  01-02-2020 02:14  01-01-2020 20:14
# 3  01-01-2020 17:50  01-01-2020 23:50  01-02-2020 07:50  01-02-2020 01:50
#
#            Giappone           Brasile           Messico            Italia
# 0  01-01-2020 13:16  01-01-2020 01:16  12-31-2019 22:16  01-01-2020 05:16
# 1  01-01-2020 19:20  01-01-2020 07:20  01-01-2020 04:20  01-01-2020 11:20
# 2  01-02-2020 02:14  01-01-2020 14:14  01-01-2020 11:14  01-01-2020 18:14
# 3  01-02-2020 07:50  01-01-2020 19:50  01-01-2020 16:50  01-01-2020 23:50

# %% [markdown]
# Controlliamo che il dizionario delle nuove rilevazioni contenga circa 8/9000 dati che è il numero solitamente rilevato.

# %%
new_data = []
for video in j_file:
    c = video["country_name"]
    for tms in times[c]:
        if video["timestamp"] == tms:
            new_data.append(video)
            
len(new_data)
# Out:
# 8939

# %% [markdown]
# Verifichiamo che ogni nazione contenga ora 4 rilevazioni per giornata.

# %%
c_data_new = {}
for e in new_data:
    t = e["timestamp"]
    c = e["country_name"]
    if c not in c_data_new.keys(): #se non ho già inserito il country
        c_data_new[c] = [t]
    else:
        if t not in c_data_new[c] : #se non ho già inserito questa data in quel country
            c_data_new[c].append(t)
c_data_new
# Out:
# {'Brasile': ['01-01-2020 01:16',
#   '01-01-2020 07:20',
#   '01-01-2020 14:14',
#   '01-01-2020 19:50'],
#  'Canada': ['12-31-2019 23:16',
#   '01-01-2020 05:20',
#   '01-01-2020 12:14',
#   '01-01-2020 17:50'],
#  'Germania': ['01-01-2020 05:16',
#   '01-01-2020 11:20',
#   '01-01-2020 18:14',
#   '01-01-2020 23:50'],
#  'Francia': ['01-01-2020 05:16',
#   '01-01-2020 11:20',
#   '01-01-2020 18:14',
#   '01-01-2020 23:50'],
#  'Regno Unito': ['01-01-2020 04:16',
#   '01-01-2020 10:20',
#   '01-01-2020 17:14',
#   '01-01-2020 22:50'],
#  'India': ['01-01-2020 09:16',
#   '01-01-2020 15:20',
#   '01-01-2020 22:14',
#   '01-02-2020 03:50'],
#  'Italia': ['01-01-2020 05:16',
#   '01-01-2020 11:20',
#   '01-01-2020 18:14',
#   '01-01-2020 23:50'],
#  'Giappone': ['01-01-2020 13:16',
#   '01-01-2020 19:20',
#   '01-02-2020 02:14',
#   '01-02-2020 07:50'],
#  'Corea del sud': ['01-01-2020 13:16',
#   '01-01-2020 19:20',
#   '01-02-2020 02:14',
#   '01-02-2020 07:50'],
#  'Messico': ['12-31-2019 22:16',
#   '01-01-2020 04:20',
#   '01-01-2020 11:14',
#   '01-01-2020 16:50'],
#  'Russia': ['01-01-2020 07:16',
#   '01-01-2020 13:20',
#   '01-01-2020 20:14',
#   '01-02-2020 01:50'],
#  'USA': ['12-31-2019 23:16',
#   '01-01-2020 05:20',
#   '01-01-2020 12:14',
#   '01-01-2020 17:50']}

# %% [markdown]
# Salviamo i file in json in modo che siano Immediatamente caricabili in MongoDB

# %%
with open('json_fixed\\' + file_json, 'w') as outfile:
    json.dump(new_data, outfile)
